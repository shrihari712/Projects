# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Lenovo\Downloads\chipotle.tsv",sep='\t')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df['choice_description']=df['choice_description'].replace(np.nan,"Not available")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                         Not available     $2.39
# ...

# %%
df[df.duplicated()]
# Out:
#       order_id  quantity                            item_name  \
# 238        103         1                        Steak Burrito
# 248        108         1                          Canned Soda
# 297        129         1                        Steak Burrito
# 381        165         1                    Canned Soft Drink
# 484        205         1                         Chicken Bowl
# 567        233         1                    Canned Soft Drink
# 617        254         1                                Chips
# 684        282         1                    Canned Soft Drink
# 773        319         1                         Chicken Bowl
# 908        376         1                        Steak Burrito
# 924        381         1                   Chicken Soft Tacos
# 1003       412         1                        Bottled Water
# 1117       462         1                      Chicken Burrito
# 1203       491         1                      Chicken Burrito
# ...

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (4563, 5)

# %%
df['item_price']=df['item_price'].apply(lambda x:x.replace("$",""))
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11260\3243802969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['item_price']=df['item_price'].apply(lambda x:x.replace("$",""))
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# ...

# %%
df['item_price'] = df['item_price'].astype(float)
df.head(10)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11260\1949072937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['item_price'] = df['item_price'].astype(float)
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# ...

# %%
#Question 1
a=df.groupby('item_name').sum()
a.sort_values(['quantity'],ascending=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11260\3999661221.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a=df.groupby('item_name').sum()
#                                        order_id  quantity  item_price
# item_name
# Chicken Bowl                             704980       752     7259.75
# Chicken Burrito                          490718       584     5509.57
# Chips and Guacamole                      443669       501     2178.79
# Steak Burrito                            327829       383     3818.94
# Canned Soft Drink                        296817       340      425.00
# Chips                                    204975       227      487.89
# Steak Bowl                               192568       220     2250.94
# ...

# %%
#Question 2
df['choice_description'].value_counts()
# Out:
# Not available                                                                                                                                    1228
# [Diet Coke]                                                                                                                                       133
# [Coke]                                                                                                                                            115
# [Sprite]                                                                                                                                           77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                                             41
#                                                                                                                                                  ...
# ...

# %%
#Question 3
total_item=df.quantity.sum()
total_item
# Out:
# 4913

# %%
#Question 4
df["total_price"]=df['quantity']*df['item_price']
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11260\2911329690.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["total_price"]=df['quantity']*df['item_price']
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# ...

# %%
revenue=df.total_price.sum()
revenue
# Out:
# 38914.11

# %%
#Question 5
order=df.order_id.value_counts().count()
order
# Out:
# 1834

# %%
#question 6
b=df.groupby('order_id').sum()
b
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11260\2696879499.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   b=df.groupby('order_id').sum()
#           quantity  item_price  total_price
# order_id
# 1                4       11.56        11.56
# 2                2       16.98        33.96
# 3                2       12.67        12.67
# 4                2       21.00        21.00
# 5                2       13.70        13.70
# ...            ...         ...          ...
# 1830             2       23.00        23.00
# 1831             3       12.90        12.90
# 1832             2       13.20        13.20
# 1833             2       23.50        23.50
# 1834             3       28.75        28.75
#
# [1834 rows x 3 columns]

# %%
avg_revenue_per_order=b['total_price'].mean()
avg_revenue_per_order
# Out:
# 21.218162486368595

# %%
#question 7
df.item_name.value_counts().count()
# Out:
# 50
